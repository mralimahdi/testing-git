# %% [markdown]
# For slideshow from single folder
#
# Folder structure:
#
# folder/
# ├── img1.jpg
# ├── img2.jpg
# ├── img3.jpg
# ├── ...
# └── ...

# %%
import cv2
import os

path = (r"C:\Users\DELL\Desktop\6th semester\mids\Machine Vision\course\mid coding\ColorClassification\Black")

list_name = os.listdir(path) # an rray string of all the file names in the directory for the given path using .listdir() method of os module

for name in list_name: #name is a variable that will take each file name from the list_name array one by one in each iteration of the loop
    if name.lower().endswith(('.jpg', '.png')): # condition to check if the file name ends with .jpg or .png (case-insensitive)

        img_name = os.path.join(path, name) # Full Image Path Banana

        img = cv2.imread(img_name) # Read the image using cv2.imread() method and store it in a variable called img
        cv2.imshow("UIIT", img) # all images will be shown in origional size because we are not resizing the image
        cv2.waitKey(100)
        x=0

cv2.destroyAllWindows()
